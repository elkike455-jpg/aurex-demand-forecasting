# %% [markdown]
# # Deep Benchmark Plan
#
# This notebook defines the benchmark scope for deep challenger models across the three project datasets:
#
# - `M5 / Walmart`
# - `Favorita`
# - `Amazon`
#
# The benchmark goal is to compare deep architectures against classical and intermittent-demand models under a regime-aware perspective.

# %% [markdown]
# ## Target Deep Challengers
#
# - `LSTM`
# - `GRU`
# - `TCN`
# - `DeepAR`
#
# Optional later extensions:
#
# - `Informer`
# - `TFT`
# - `N-BEATS`
# - `LSTM-Transformer`

# %%
benchmark_scope = {
    'datasets': ['m5', 'favorita', 'amazon'],
    'classical_models': ['SARIMAX'],
    'intermittent_models': ['HURDLE', 'TSB', 'Croston-SBA'],
    'deep_models': ['LSTM', 'GRU', 'TCN', 'DeepAR'],
    'regimes': ['stable', 'variable', 'intermittent', 'lumpy'],
    'metrics': ['MAE', 'RMSE', 'sMAPE'],
}

benchmark_scope

# %% [markdown]
# ## Working Notes
#
# - Use deep models as `challenger models`, not as the core method.
# - Evaluate globally and by regime.
# - Use all three datasets to avoid overfitting the argument to a single retail environment.
